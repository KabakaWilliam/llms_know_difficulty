# %%
from llm_sandbox import SandboxSession, InteractiveSandboxSession

# %%
with InteractiveSandboxSession(
    lang="python",
    kernel_type="ipython",
    history_size=200,
) as session:
    session.run("value = 21 * 2")
    result = session.run("print(f'Result: {value}')")
    print(result.stdout)  # -> Result: 42

    # Use magic command to install libraries
    session.run("%pip install pandas")
    result = session.run("import pandas as pd; print(pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]}))")
    print(result.stdout)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 with InteractiveSandboxSession(
#       2     lang="python",
#       3     kernel_type="ipython",
#       4     history_size=200,
#       5 ) as session:
#       6     session.run("value = 21 * 2")
#       7     result = session.run("print(f'Result: {value}')")
#
# File /opt/anaconda/envs/yugi/lib/python3.12/site-packages/llm_sandbox/interactive.py:158, in InteractiveSandboxSession.__init__(self, backend, lang, kernel_type, max_memory, history_size, timeout, runtime_configs, **kwargs)
#     155 kwargs.setdefault("lang", SupportedLanguage.PYTHON)
#     157 # Create the backend session using composition
# --> 158 self._backend_session = _create_backend_session(
#     159     backend=backend,
#     160     runtime_configs=runtime_configs,
#     161     **kwargs,
#     162 )
#     164 # Initialize BaseSession with the same config as backend session
#     165 super().__init__(config=self._backend_session.config)
#
# File /opt/anaconda/envs/yugi/lib/python3.12/site-packages/llm_sandbox/interactive.py:84, in _create_backend_session(backend, runtime_configs, **kwargs)
#      82 match backend:
#      83     case SandboxBackend.DOCKER:
# ---> 84         from llm_sandbox.docker import SandboxDockerSession
#      86         return SandboxDockerSession(runtime_configs=runtime_configs, **kwargs)
#      87     case SandboxBackend.PODMAN:
#
# File /opt/anaconda/envs/yugi/lib/python3.12/site-packages/llm_sandbox/docker.py:6
#       3 from typing import TYPE_CHECKING, Any
#       5 import docker
# ----> 6 from docker.errors import ImageNotFound, NotFound
#       8 from llm_sandbox.const import DefaultImage, SupportedLanguage
#       9 from llm_sandbox.core.config import SessionConfig
#
# ModuleNotFoundError: No module named 'docker.errors'
