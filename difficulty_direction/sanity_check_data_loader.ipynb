# %%
import pandas as pd
import os

# %%
train_data_path = "/VData/linna4335/llms_know_difficult/predicting_learnability/data/MATH_DeepSeek-R1-Distill-Qwen-1.5B-SR_train.parquet"

# %%
og_train_df = pd.read_parquet(train_data_path)

# %%
og_train_df.describe()
# Out:
#            correct   total  success_rate
# count  2000.000000  2000.0   2000.000000
# mean     34.553000    50.0      0.691060
# std      19.577125     0.0      0.391542
# min       0.000000    50.0      0.000000
# 25%      20.000000    50.0      0.400000
# 50%      46.000000    50.0      0.920000
# 75%      50.000000    50.0      1.000000
# max      50.000000    50.0      1.000000
